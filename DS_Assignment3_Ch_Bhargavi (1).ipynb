# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_excel(r'C:\Users\DELL\Downloads\airline_passenger_satisfaction.xlsx')
display(df)
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 0            1    Male   48    First-time       Business      Business
# 1            2  Female   35     Returning       Business      Business
# 2            3    Male   41     Returning       Business      Business
# 3            4    Male   50     Returning       Business      Business
# 4            5  Female   49     Returning       Business      Business
# ...        ...     ...  ...           ...            ...           ...
# 129875  129876    Male   28     Returning       Personal  Economy Plus
# 129876  129877    Male   41     Returning       Personal  Economy Plus
# 129877  129878    Male   42     Returning       Personal  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
# 129879  129880  Female   20     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 0                   821                2            5.0
# ...

# %%
filtered_df = df[df['ID'] <30]#filtering
print("\nFiltered DataFrame:")
display(filtered_df)
# Out:
# Filtered DataFrame:
#     ID  Gender  Age Customer Type Type of Travel         Class  \
# 0    1    Male   48    First-time       Business      Business
# 1    2  Female   35     Returning       Business      Business
# 2    3    Male   41     Returning       Business      Business
# 3    4    Male   50     Returning       Business      Business
# 4    5  Female   49     Returning       Business      Business
# 5    6    Male   43     Returning       Business      Business
# 6    7    Male   43     Returning       Business      Business
# 7    8  Female   60     Returning       Business      Business
# 8    9    Male   50     Returning       Business      Business
# 9   10  Female   38     Returning       Business      Business
# 10  11  Female   28    First-time       Business      Business
# 11  12  Female   27    First-time       Business      Business
# 12  13    Male   24    First-time       Business       Economy
# 13  14    Male    9     Returning       Personal      Business
# ...

# %%
print("First five rows:")
display(filtered_df.head(5))
# Out:
# First five rows:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                     3.0
# 1               26           39.0                                     2.0
# 2                0            0.0                                     4.0
# 3                0            0.0                                     2.0
# 4                0            1.0                                     3.0
#
# ...

# %%
print("\nMissing Values:")#finding missing values
print(filtered_df.isnull().sum())
# Out:
# Missing Values:
# ID                                        0
# Gender                                    0
# Age                                       0
# Customer Type                             0
# Type of Travel                            0
# Class                                     0
# Flight Distance                           0
# Departure Delay                           0
# Arrival Delay                             0
# Departure and Arrival Time Convenience    1
# Ease of Online Booking                    1
# Check-in Service                          0
# Online Boarding                           0
# Gate Location                             0
# On-board Service                          1
# Seat Comfort                              1
# Leg Room Service                          0
# Cleanliness                               0
# Food and Drink                            0
# In-flight Service                         1
# In-flight Wifi Service                    0
# ...

# %%
print("\nBasic Statistics:")
display(filtered_df.describe())
# Out:
# Basic Statistics:
#               ID        Age  Flight Distance  Departure Delay  Arrival Delay  \
# count  29.000000  29.000000        29.000000        29.000000      29.000000
# mean   15.000000  44.551724      1541.172414         5.758621       9.448276
# std     8.514693  16.808982      1084.575923        13.840043      18.534883
# min     1.000000   9.000000       421.000000         0.000000       0.000000
# 25%     8.000000  38.000000       821.000000         0.000000       0.000000
# 50%    15.000000  48.000000       853.000000         0.000000       0.000000
# 75%    22.000000  52.000000      2168.000000         4.000000       5.000000
# max    29.000000  77.000000      3788.000000        68.000000      76.000000
#
#        Departure and Arrival Time Convenience  Ease of Online Booking  \
# count                               28.000000               28.000000
# mean                                 3.250000                2.642857
# ...

# %%
print("\nData information:")
print(filtered_df.info())
# Out:
# Data information:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 0 to 28
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   ID                                      29 non-null     int64
#  1   Gender                                  29 non-null     object
#  2   Age                                     29 non-null     int64
#  3   Customer Type                           29 non-null     object
#  4   Type of Travel                          29 non-null     object
#  5   Class                                   29 non-null     object
#  6   Flight Distance                         29 non-null     int64
#  7   Departure Delay                         29 non-null     int64
#  8   Arrival Delay                           29 non-null     float64
#  9   Departure and Arrival Time Convenience  28 non-null     float64
# ...

# %%
filtered_df = filtered_df.fillna(0).mean()
print("\nDataFrame with filled missing values:")
print(filtered_df)
# Out:
# DataFrame with filled missing values:
# ID                                          15.000000
# Age                                         44.551724
# Flight Distance                           1541.172414
# Departure Delay                              5.758621
# Arrival Delay                                9.448276
# Departure and Arrival Time Convenience       3.137931
# Ease of Online Booking                       2.551724
# Check-in Service                             3.586207
# Online Boarding                              3.448276
# Gate Location                                3.000000
# On-board Service                             3.448276
# Seat Comfort                                 3.896552
# Leg Room Service                             3.655172
# Cleanliness                                  3.793103
# Food and Drink                               3.379310
# In-flight Service                            3.896552
# In-flight Wifi Service                       2.620690
# ...

# %%
print("\nMissing Values:")#finding missing values
print(filtered_df.isnull().sum())
# Out:
# Missing Values:
# 0

# %%
# Remove duplicate rows from the DataFrame
df_cleaned = filtered_df.drop_duplicates()
print("\nCleaned data:")
print(df_cleaned)
# Out:
# Cleaned data:
# ID                                          15.000000
# Age                                         44.551724
# Flight Distance                           1541.172414
# Departure Delay                              5.758621
# Arrival Delay                                9.448276
# Departure and Arrival Time Convenience       3.137931
# Ease of Online Booking                       2.551724
# Check-in Service                             3.586207
# Online Boarding                              3.448276
# Gate Location                                3.000000
# Seat Comfort                                 3.896552
# Leg Room Service                             3.655172
# Cleanliness                                  3.793103
# Food and Drink                               3.379310
# In-flight Wifi Service                       2.620690
# In-flight Entertainment                      3.965517
# Baggage Handling                             3.931034
# dtype: float64

# %%
df.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                     3.0
# 1               26           39.0                                     2.0
# 2                0            0.0                                     4.0
# 3                0            0.0                                     2.0
# 4                0            1.0                                     3.0
#
# ...

# %%
df.describe()
# Out:
#                   ID            Age  Flight Distance  Departure Delay  \
# count  129880.000000  129880.000000    129880.000000    129880.000000
# mean    64940.500000      39.427957      1190.316392        14.713713
# std     37493.270818      15.119360       997.452477        38.071126
# min         1.000000       7.000000        31.000000         0.000000
# 25%     32470.750000      27.000000       414.000000         0.000000
# 50%     64940.500000      40.000000       844.000000         0.000000
# 75%     97410.250000      51.000000      1744.000000        12.000000
# max    129880.000000      85.000000      4983.000000      1592.000000
#
#        Arrival Delay  Departure and Arrival Time Convenience  \
# count  129487.000000                           129879.000000
# mean       15.091129                                3.057592
# std        38.465650                                1.526745
# min         0.000000                                0.000000
# ...

# %%
plt.hist(df["Flight Distance"], bins=30)
# Out:
# (array([8.5040e+03, 1.7748e+04, 1.5872e+04, 1.4516e+04, 9.1560e+03,
#         1.0731e+04, 6.6270e+03, 3.8340e+03, 4.1030e+03, 4.8160e+03,
#         4.1500e+03, 3.0790e+03, 2.9450e+03, 2.7830e+03, 3.8090e+03,
#         3.1030e+03, 2.0210e+03, 1.7900e+03, 1.6510e+03, 1.6760e+03,
#         1.7040e+03, 1.6480e+03, 1.7050e+03, 1.7470e+03, 8.4000e+01,
#         2.3000e+01, 0.0000e+00, 1.4000e+01, 6.0000e+00, 3.5000e+01]),
#  array([  31.        ,  196.06666667,  361.13333333,  526.2       ,
#          691.26666667,  856.33333333, 1021.4       , 1186.46666667,
#         1351.53333333, 1516.6       , 1681.66666667, 1846.73333333,
#         2011.8       , 2176.86666667, 2341.93333333, 2507.        ,
#         2672.06666667, 2837.13333333, 3002.2       , 3167.26666667,
#         3332.33333333, 3497.4       , 3662.46666667, 3827.53333333,
#         3992.6       , 4157.66666667, 4322.73333333, 4487.8       ,
#         4652.86666667, 4817.93333333, 4983.        ]),
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(data=df,x=df["Departure Delay"])
# Out:
# <Axes: xlabel='Departure Delay'>
